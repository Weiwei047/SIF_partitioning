# %%
# %reset -f

# %%
import warnings
warnings.filterwarnings("ignore")
import os 
import numpy as np
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
import matplotlib
import tensorflow as tf
import tensorflow.keras.backend as K

from scipy import stats
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler 
from tensorflow import keras
from tensorflow.keras.layers import Input, Dense, Lambda, Activation, Dropout
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.constraints import NonNeg
from tensorflow.python.framework.ops import disable_eager_execution
disable_eager_execution()
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

from utils.NNSIF_model import get_prediction_model, get_trainable_model, layer_output, fluxes_SIF_predict
from utils.preprocess import include_predictions, div_daynight, standard_x, split_train_test
from utils.plot import regression_line, GPP_SIF_dependence


# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# %load_ext autoreload
# %autoreload 2

# change font
matplotlib.rcParams['font.sans-serif'] = "Arial"
matplotlib.rcParams['font.family'] = "sans-serif"
plt.rcParams["legend.frameon"] = False
plt.rcParams['savefig.dpi'] = 310
plt.rcParams['font.size'] = 13

# %% [markdown]
# ### 1. import & preprocess the data

# %%
os.chdir('/Users/weiweizhan/Desktop/Weiwei_Zhan/Projects/SIF_partition/DATA/')

data_NN = pd.read_csv('./FinalData/test_data_SCOPE.csv',index_col=0)
data_NN.index = pd.to_datetime(data_NN.index)

# %%
train_dataset, test_dataset, NEE_norm, SIF_norm = split_train_test(data_NN,seed=31,
                                                   EV1_label = ['Tair','RH','SWC','PAR','u','LAI'], 
                                                   EV2_label = ['Tair','SWC','u','LAI'], 
                                                   EV3_label = ['Tair','RH','SWC'],
                                                   var_NEE = 'NEE_canopy', var_SIF = 'SIFcanopy_760nm',
                                                   flux_label = ['GPP_canopy','Reco_canopy','Reco_NT','GPP_NT','Reco_DT','GPP_DT'])

train,EV1_train1,EV2_train1,EV3_train1,NEE_train1,SIF_train1,flux_train,label_train = train_dataset
test, EV1_test1, EV2_test1, EV3_test1, NEE_test, SIF_test, flux_test, label_test  = test_dataset

# %% [markdown]
# ### 2. train the $NN_{SIF}$ model

# %%
prediction_model = get_prediction_model(n_neuron=64,
                                        input1_shape=EV1_train1.shape[1],
                                        input2_shape=EV2_train1.shape[1],
                                        input3_shape=EV3_train1.shape[1])
trainable_model  = get_trainable_model(prediction_model,
                                       input1_shape=EV1_train1.shape[1],
                                       input2_shape=EV2_train1.shape[1],
                                       input3_shape=EV3_train1.shape[1])

optimizer1 = keras.optimizers.Adam(lr=0.002)
trainable_model.compile(optimizer=optimizer1, loss=None)

assert len(trainable_model.layers[-1].trainable_weights) == 2  
assert len(trainable_model.losses) == 1

hist = trainable_model.fit([label_train,EV1_train1,EV2_train1,EV3_train1,NEE_train1,SIF_train1], 
                            epochs=60, batch_size=64, verbose=1,validation_split = 0.3)
# Out:
# Train on 3210 samples, validate on 1376 samples
# Epoch 1/60
# 3210/3210 [==============================] - 0s 52us/sample - loss: 0.0080 - mse_nee: 0.0668 - mse_sif: 0.0344 - val_loss: -0.1977 - val_mse_nee: 0.0066 - val_mse_sif: 0.0049
# Epoch 2/60
# 3210/3210 [==============================] - 0s 35us/sample - loss: -0.3031 - mse_nee: 0.0050 - mse_sif: 0.0029 - val_loss: -0.4136 - val_mse_nee: 0.0041 - val_mse_sif: 0.0017
# Epoch 3/60
# 3210/3210 [==============================] - 0s 33us/sample - loss: -0.5144 - mse_nee: 0.0035 - mse_sif: 0.0016 - val_loss: -0.6218 - val_mse_nee: 0.0033 - val_mse_sif: 0.0015
# Epoch 4/60
# 3210/3210 [==============================] - 0s 36us/sample - loss: -0.7217 - mse_nee: 0.0029 - mse_sif: 0.0015 - val_loss: -0.8285 - val_mse_nee: 0.0033 - val_mse_sif: 9.7817e-04
# Epoch 5/60
# 3210/3210 [==============================] - 0s 35us/sample - loss: -0.9285 - mse_nee: 0.0026 - mse_sif: 0.0010 - val_loss: -1.0349 - val_mse_nee: 0.0027 - val_mse_sif: 9.1668e-04
# Epoch 6/60
# 3210/3210 [==============================] - 0s 34us/sample - loss: -1.1345 - mse_nee: 0.0022 - mse_sif: 9.4365e-04 - val_loss: -1.2391 - val_mse_nee: 0.0031 - val_mse_sif: 8.5651e-04
# Epoch 7/60
# 3210/3210 [==============================] - 0s 33us/sample - loss: -1.3399 - mse_nee: 0.0019 - mse_sif: 9.2824e-04 - val_loss: -1.4461 - val_mse_nee: 0.0020 - val_mse_sif: 7.6044e-04
# Epoch 8/60
# 3210/3210 [==============================] - 0s 35us/sample - loss: -1.5455 - mse_nee: 0.0016 - mse_sif: 7.8133e-04 - val_loss: -1.6505 - val_mse_nee: 0.0019 - val_mse_sif: 9.0623e-04
# Epoch 9/60
# 3210/3210 [==============================] - 0s 33us/sample - loss: -1.7508 - mse_nee: 0.0014 - mse_sif: 6.9617e-04 - val_loss: -1.8560 - val_mse_nee: 0.0016 - val_mse_sif: 7.2399e-04
# Epoch 10/60
# 3210/3210 [==============================] - 0s 33us/sample - loss: -1.9547 - mse_nee: 0.0014 - mse_sif: 8.4031e-04 - val_loss: -2.0606 - val_mse_nee: 0.0014 - val_mse_sif: 8.7042e-04
# Epoch 11/60
# 3210/3210 [==============================] - 0s 33us/sample - loss: -2.1589 - mse_nee: 0.0012 - mse_sif: 8.6572e-04 - val_loss: -2.2636 - val_mse_nee: 0.0018 - val_mse_sif: 6.9469e-04
# Epoch 12/60
# 3210/3210 [==============================] - 0s 33us/sample - loss: -2.3642 - mse_nee: 0.0011 - mse_sif: 6.1314e-04 - val_loss: -2.4674 - val_mse_nee: 0.0014 - val_mse_sif: 9.3476e-04
# Epoch 13/60
# 3210/3210 [==============================] - 0s 35us/sample - loss: -2.5647 - mse_nee: 0.0013 - mse_sif: 0.0012 - val_loss: -2.6706 - val_mse_nee: 0.0012 - val_mse_sif: 0.0012
# Epoch 14/60
# 3210/3210 [==============================] - 0s 33us/sample - loss: -2.7725 - mse_nee: 9.6485e-04 - mse_sif: 5.3429e-04 - val_loss: -2.8757 - val_mse_nee: 0.0011 - val_mse_sif: 7.7914e-04
# Epoch 15/60
# 3210/3210 [==============================] - 0s 33us/sample - loss: -2.9745 - mse_nee: 9.9638e-04 - mse_sif: 7.7418e-04 - val_loss: -3.0801 - val_mse_nee: 0.0011 - val_mse_sif: 6.9353e-04
# Epoch 16/60
# 3210/3210 [==============================] - 0s 34us/sample - loss: -3.1810 - mse_nee: 8.9436e-04 - mse_sif: 4.0726e-04 - val_loss: -3.2852 - val_mse_nee: 0.0012 - val_mse_sif: 3.5467e-04
# Epoch 17/60
# 3210/3210 [==============================] - 0s 36us/sample - loss: -3.3827 - mse_nee: 9.2839e-04 - mse_sif: 7.0301e-04 - val_loss: -3.4750 - val_mse_nee: 0.0022 - val_mse_sif: 0.0016
# Epoch 18/60
# 3210/3210 [==============================] - 0s 33us/sample - loss: -3.5835 - mse_nee: 0.0011 - mse_sif: 7.5479e-04 - val_loss: -3.6920 - val_mse_nee: 0.0010 - val_mse_sif: 4.2143e-04
# Epoch 19/60
# 3210/3210 [==============================] - 0s 34us/sample - loss: -3.7912 - mse_nee: 8.4554e-04 - mse_sif: 4.0270e-04 - val_loss: -3.8955 - val_mse_nee: 0.0011 - val_mse_sif: 3.4921e-04
# Epoch 20/60
# 3210/3210 [==============================] - 0s 35us/sample - loss: -3.9945 - mse_nee: 8.3738e-04 - mse_sif: 4.0518e-04 - val_loss: -4.0981 - val_mse_nee: 0.0010 - val_mse_sif: 3.5501e-04
# Epoch 21/60
# 3210/3210 [==============================] - 0s 33us/sample - loss: -4.1911 - mse_nee: 9.9723e-04 - mse_sif: 8.4549e-04 - val_loss: -4.2828 - val_mse_nee: 0.0012 - val_mse_sif: 0.0016
# Epoch 22/60
# 3210/3210 [==============================] - 0s 37us/sample - loss: -4.3972 - mse_nee: 9.2493e-04 - mse_sif: 5.2551e-04 - val_loss: -4.5003 - val_mse_nee: 0.0013 - val_mse_sif: 3.8552e-04
# Epoch 23/60
# 3210/3210 [==============================] - 0s 35us/sample - loss: -4.6025 - mse_nee: 7.8823e-04 - mse_sif: 4.2401e-04 - val_loss: -4.7077 - val_mse_nee: 9.1415e-04 - val_mse_sif: 2.9358e-04
# Epoch 24/60
# 3210/3210 [==============================] - 0s 33us/sample - loss: -4.8071 - mse_nee: 7.3977e-04 - mse_sif: 2.9570e-04 - val_loss: -4.9080 - val_mse_nee: 9.1972e-04 - val_mse_sif: 4.4010e-04
# Epoch 25/60
# 3210/3210 [==============================] - 0s 37us/sample - loss: -5.0067 - mse_nee: 8.0558e-04 - mse_sif: 4.3525e-04 - val_loss: -5.1107 - val_mse_nee: 8.5209e-04 - val_mse_sif: 4.7076e-04
# Epoch 26/60
# 3210/3210 [==============================] - 0s 35us/sample - loss: -5.2116 - mse_nee: 7.1730e-04 - mse_sif: 3.3565e-04 - val_loss: -5.3142 - val_mse_nee: 9.3699e-04 - val_mse_sif: 2.4603e-04
# Epoch 27/60
# 3210/3210 [==============================] - 0s 35us/sample - loss: -5.4124 - mse_nee: 7.5235e-04 - mse_sif: 3.7688e-04 - val_loss: -5.5015 - val_mse_nee: 0.0012 - val_mse_sif: 8.8383e-04
# Epoch 28/60
# 3210/3210 [==============================] - 0s 36us/sample - loss: -5.6082 - mse_nee: 8.5784e-04 - mse_sif: 5.8009e-04 - val_loss: -5.6976 - val_mse_nee: 0.0012 - val_mse_sif: 0.0011
# Epoch 29/60
# 3210/3210 [==============================] - 0s 33us/sample - loss: -5.8095 - mse_nee: 8.3398e-04 - mse_sif: 5.3965e-04 - val_loss: -5.9137 - val_mse_nee: 9.4937e-04 - val_mse_sif: 3.7757e-04
# Epoch 30/60
# 3210/3210 [==============================] - 0s 34us/sample - loss: -6.0152 - mse_nee: 7.2505e-04 - mse_sif: 3.6808e-04 - val_loss: -6.1073 - val_mse_nee: 0.0010 - val_mse_sif: 6.5150e-04
# Epoch 31/60
# 3210/3210 [==============================] - 0s 35us/sample - loss: -6.2120 - mse_nee: 7.7919e-04 - mse_sif: 4.7352e-04 - val_loss: -6.3160 - val_mse_nee: 8.9761e-04 - val_mse_sif: 3.2037e-04
# Epoch 32/60
# 3210/3210 [==============================] - 0s 33us/sample - loss: -6.4159 - mse_nee: 7.7680e-04 - mse_sif: 3.1531e-04 - val_loss: -6.5079 - val_mse_nee: 9.8420e-04 - val_mse_sif: 4.4077e-04
# Epoch 33/60
# 3210/3210 [==============================] - 0s 37us/sample - loss: -6.6179 - mse_nee: 7.3354e-04 - mse_sif: 2.7682e-04 - val_loss: -6.7109 - val_mse_nee: 9.2244e-04 - val_mse_sif: 4.5941e-04
# Epoch 34/60
# 3210/3210 [==============================] - 0s 42us/sample - loss: -6.8205 - mse_nee: 6.9984e-04 - mse_sif: 2.2519e-04 - val_loss: -6.9104 - val_mse_nee: 9.2091e-04 - val_mse_sif: 4.0515e-04
# Epoch 35/60
# 3210/3210 [==============================] - 0s 38us/sample - loss: -7.0178 - mse_nee: 7.0320e-04 - mse_sif: 2.8918e-04 - val_loss: -7.1089 - val_mse_nee: 9.7525e-04 - val_mse_sif: 3.2358e-04
# Epoch 36/60
# 3210/3210 [==============================] - 0s 35us/sample - loss: -7.2118 - mse_nee: 7.2106e-04 - mse_sif: 3.4856e-04 - val_loss: -7.2892 - val_mse_nee: 0.0013 - val_mse_sif: 3.5591e-04
# Epoch 37/60
# 3210/3210 [==============================] - 0s 40us/sample - loss: -7.4026 - mse_nee: 7.6107e-04 - mse_sif: 4.3604e-04 - val_loss: -7.5059 - val_mse_nee: 8.4516e-04 - val_mse_sif: 3.5787e-04
# Epoch 38/60
# 3210/3210 [==============================] - 0s 38us/sample - loss: -7.6095 - mse_nee: 6.9584e-04 - mse_sif: 3.0489e-04 - val_loss: -7.6897 - val_mse_nee: 0.0010 - val_mse_sif: 4.2349e-04
# Epoch 39/60
# 3210/3210 [==============================] - 0s 36us/sample - loss: -7.8026 - mse_nee: 6.9672e-04 - mse_sif: 3.3819e-04 - val_loss: -7.9024 - val_mse_nee: 7.8987e-04 - val_mse_sif: 3.1092e-04
# Epoch 40/60
# 3210/3210 [==============================] - 0s 34us/sample - loss: -8.0062 - mse_nee: 6.7829e-04 - mse_sif: 2.4270e-04 - val_loss: -8.0816 - val_mse_nee: 9.7356e-04 - val_mse_sif: 4.0832e-04
# Epoch 41/60
# 3210/3210 [==============================] - 0s 34us/sample - loss: -8.1928 - mse_nee: 6.9188e-04 - mse_sif: 3.5873e-04 - val_loss: -8.2593 - val_mse_nee: 0.0012 - val_mse_sif: 4.0413e-04
# Epoch 42/60
# 3210/3210 [==============================] - 0s 33us/sample - loss: -8.3864 - mse_nee: 6.9120e-04 - mse_sif: 3.4421e-04 - val_loss: -8.4616 - val_mse_nee: 9.9094e-04 - val_mse_sif: 3.0289e-04
# Epoch 43/60
# 3210/3210 [==============================] - 0s 36us/sample - loss: -8.5900 - mse_nee: 6.5261e-04 - mse_sif: 2.4449e-04 - val_loss: -8.6714 - val_mse_nee: 7.7070e-04 - val_mse_sif: 3.7075e-04
# Epoch 44/60
# 3210/3210 [==============================] - 0s 37us/sample - loss: -8.7752 - mse_nee: 6.8023e-04 - mse_sif: 3.0777e-04 - val_loss: -8.8676 - val_mse_nee: 7.9970e-04 - val_mse_sif: 2.5751e-04
# Epoch 45/60
# 3210/3210 [==============================] - 0s 34us/sample - loss: -8.9534 - mse_nee: 6.7304e-04 - mse_sif: 4.5421e-04 - val_loss: -8.9881 - val_mse_nee: 9.9432e-04 - val_mse_sif: 7.0159e-04
# Epoch 46/60
# 3210/3210 [==============================] - 0s 34us/sample - loss: -9.1297 - mse_nee: 7.3443e-04 - mse_sif: 4.4295e-04 - val_loss: -9.2417 - val_mse_nee: 7.7731e-04 - val_mse_sif: 2.7349e-04
# Epoch 47/60
# 3210/3210 [==============================] - 0s 38us/sample - loss: -9.3523 - mse_nee: 6.1360e-04 - mse_sif: 2.5048e-04 - val_loss: -9.4276 - val_mse_nee: 8.0575e-04 - val_mse_sif: 2.4704e-04
# Epoch 48/60
# 3210/3210 [==============================] - 0s 32us/sample - loss: -9.5310 - mse_nee: 6.2959e-04 - mse_sif: 3.0686e-04 - val_loss: -9.5962 - val_mse_nee: 8.0637e-04 - val_mse_sif: 3.5167e-04
# Epoch 49/60
# 3210/3210 [==============================] - 0s 32us/sample - loss: -9.7014 - mse_nee: 6.6987e-04 - mse_sif: 3.4953e-04 - val_loss: -9.6543 - val_mse_nee: 0.0011 - val_mse_sif: 8.6077e-04
# Epoch 50/60
# 3210/3210 [==============================] - 0s 35us/sample - loss: -9.8861 - mse_nee: 6.6819e-04 - mse_sif: 3.2954e-04 - val_loss: -9.9824 - val_mse_nee: 7.6732e-04 - val_mse_sif: 2.1944e-04
# Epoch 51/60
# 3210/3210 [==============================] - 0s 34us/sample - loss: -10.0798 - mse_nee: 6.3615e-04 - mse_sif: 2.7421e-04 - val_loss: -10.1395 - val_mse_nee: 8.9155e-04 - val_mse_sif: 2.1551e-04
# Epoch 52/60
# 3210/3210 [==============================] - 0s 33us/sample - loss: -10.2635 - mse_nee: 6.5119e-04 - mse_sif: 2.3555e-04 - val_loss: -10.3153 - val_mse_nee: 8.7378e-04 - val_mse_sif: 2.3353e-04
# Epoch 53/60
# 3210/3210 [==============================] - 0s 36us/sample - loss: -10.4567 - mse_nee: 6.0453e-04 - mse_sif: 2.0880e-04 - val_loss: -10.4993 - val_mse_nee: 8.1322e-04 - val_mse_sif: 2.3332e-04
# Epoch 54/60
# 3210/3210 [==============================] - 0s 34us/sample - loss: -10.5934 - mse_nee: 6.7007e-04 - mse_sif: 3.0996e-04 - val_loss: -10.5779 - val_mse_nee: 0.0010 - val_mse_sif: 4.1478e-04
# Epoch 55/60
# 3210/3210 [==============================] - 0s 35us/sample - loss: -10.7302 - mse_nee: 7.1249e-04 - mse_sif: 3.8236e-04 - val_loss: -10.7830 - val_mse_nee: 8.4426e-04 - val_mse_sif: 3.6302e-04
# Epoch 56/60
# 3210/3210 [==============================] - 0s 33us/sample - loss: -10.9423 - mse_nee: 6.6410e-04 - mse_sif: 2.4922e-04 - val_loss: -10.9621 - val_mse_nee: 8.4580e-04 - val_mse_sif: 3.0561e-04
# Epoch 57/60
# 3210/3210 [==============================] - 0s 35us/sample - loss: -11.1385 - mse_nee: 6.0109e-04 - mse_sif: 2.0159e-04 - val_loss: -11.1539 - val_mse_nee: 8.0027e-04 - val_mse_sif: 2.4117e-04
# Epoch 58/60
# 3210/3210 [==============================] - 0s 34us/sample - loss: -11.3236 - mse_nee: 5.7770e-04 - mse_sif: 1.7260e-04 - val_loss: -11.3057 - val_mse_nee: 8.0541e-04 - val_mse_sif: 2.5703e-04
# Epoch 59/60
# 3210/3210 [==============================] - 0s 34us/sample - loss: -11.4484 - mse_nee: 6.2347e-04 - mse_sif: 2.3679e-04 - val_loss: -11.4709 - val_mse_nee: 7.8665e-04 - val_mse_sif: 2.6311e-04
# Epoch 60/60
# 3210/3210 [==============================] - 0s 34us/sample - loss: -11.6432 - mse_nee: 5.5634e-04 - mse_sif: 2.0812e-04 - val_loss: -11.6613 - val_mse_nee: 7.1514e-04 - val_mse_sif: 2.1391e-04

# %% [markdown]
# ### 3. predict carbon fluxes using the well-trained model

# %%
NEE_trainNN, GPP_trainNN, Reco_trainNN, SIF_trainNN = fluxes_SIF_predict(prediction_model,label_train,
                                                                         EV1_train1, EV2_train1, EV3_train1,
                                                                         NEE_norm, SIF_norm)
NEE_testNN, GPP_testNN, Reco_testNN, SIF_testNN = fluxes_SIF_predict(prediction_model,label_test,
                                                                     EV1_test1, EV2_test1, EV3_test1,
                                                                     NEE_norm, SIF_norm)



train = include_predictions(train,NEE_trainNN, GPP_trainNN, Reco_trainNN, SIF_trainNN)
test  = include_predictions(test,NEE_testNN, GPP_testNN, Reco_testNN, SIF_testNN)

# save the data
data_NN = pd.concat([train,test],axis=0).sort_index()
day_SC, night_SC = div_daynight(data_NN)

# %% [markdown]
# ### 4. evaluate the model predictions

# %%
fig, axes = plt.subplots(figsize=(15,3.5),ncols=4)

c_GPP,c_Reco = 'tab:blue','goldenrod'
c_NEE,c_SIF  = '#994F00','darkgreen'


xlim1,ylim1 = [-30,10], [-30,10]
xlim2,ylim2 = [0,40],[0,40]
xlim3,ylim3 = [0,12], [0,12]
xlim4,ylim4 = [0,3.], [0,3.]


data_NN.plot('NEE_NN','NEE_canopy',kind='scatter',ax=axes[0],alpha=0.5,xlim=xlim1,ylim=ylim1,c=c_NEE)
day_SC.plot('GPP_NN','GPP_canopy',kind='scatter',ax=axes[1],alpha=0.5,xlim=xlim2,ylim=ylim2,c=c_GPP) 
data_NN.plot('Reco_NN','Reco_canopy',kind='scatter',ax=axes[2],alpha=0.5,xlim=xlim3,ylim=ylim3,c=c_Reco) 
day_SC.plot('SIF_NN','SIFcanopy_760nm',kind='scatter',ax=axes[3],alpha=0.5,xlim=xlim4,ylim=ylim4,color=c_SIF) 

regression_line(data_NN.NEE_NN,data_NN.NEE_canopy,ax=axes[0],xlim=xlim1,xy=(.05,.62),num_seq='(a)',R2_3digt=True)
regression_line(day_SC.GPP_NN,day_SC.GPP_canopy,ax=axes[1],xlim=xlim2,legend=True,xy=(.05,.62),num_seq='(b)',R2_3digt=True)
regression_line(data_NN.Reco_NN,data_NN.Reco_canopy,ax=axes[2],xlim=xlim3,xy=(.05,.62),num_seq='(c)',R2_3digt=True)
regression_line(day_SC.SIF_NN,day_SC.SIFcanopy_760nm,ax=axes[3],xlim=xlim4,xy=(.05,.62),num_seq='(d)',R2_3digt=True)

var = ['NEE','GPP','ER','SIF']

for (i,ax) in enumerate(axes.flatten()):
    ax.set_xlabel('$NN_{SIF}$-predicted '+var[i]+' ($\mu mol$ $m^{-2} s^{-1}$)')
    ax.set_ylabel('SCOPE '+var[i]+' ($\mu mol$ $m^{-2} s^{-1}$)')
    if i == 3:
        ax.set_xlabel('$NN_{SIF}$-predicted '+var[i]+' ($mW \ m^{-2} nm^{-1} sr^{-1}$)')
        ax.set_ylabel('SCOPE '+var[i]+' ($mW \ m^{-2} nm^{-1} sr^{-1}$)')
        

plt.tight_layout()

# %%
fig, axes = plt.subplots(figsize=(16,4),ncols=3)

xlim = [0,3]
ylim = [0,40]

GPP_SIF_dependence(day_SC,'SIFcanopy_760nm','GPP_canopy',xlim,ylim,axes[0],'VPD','RdBu_r',fig,'VPD (kPa)',s=20,vmin=0,vmax=2)
GPP_SIF_dependence(day_SC,'SIF_NN','GPP_NN',xlim,ylim,axes[1],'VPD','RdBu_r',fig,'VPD (kPa)',s=20,vmin=0,vmax=2) 
GPP_SIF_dependence(day_SC,'SIFcanopy_760nm','GPP_NN',xlim,ylim,axes[2],'VPD','RdBu_r',fig,'VPD (kPa)',s=20,vmin=0,vmax=2) 


xlabel = ['SCOPE SIF', '$NN_{SIF}$-predicted SIF', 'SCOPE SIF']
xunit  = [' ($mW \ m^{-2} nm^{-1} sr^{-1}$)']

ylabel = ['SCOPE GPP', '$NN_{SIF}$-predicted GPP', '$NN_{SIF}$-predicted GPP']
yunit = [' ($\mu mol$ $m^{-2} s^{-1}$)']
num_seq = ['(a)','(b)','(c)','(d)']
for i,ax in enumerate(axes):
    ax.set_xlabel(xlabel[i]+xunit[0])
    ax.set_ylabel(ylabel[i]+yunit[0])
    ax.annotate(num_seq[i],xy=(.05,.9), xycoords='axes fraction',fontweight='bold',fontsize=13)
    ax.set_xlim(xlim)
    ax.set_ylim(ylim)
plt.tight_layout()
